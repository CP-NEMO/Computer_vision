# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 921s 5us/step

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         32896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               256500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 555,450
# Trainable params: 555,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist = model.fit(x_train, y_train, batch_size=32, epochs=25,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Epoch 1/25
#
# Epoch 00001: val_loss improved from inf to 1.43090, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 1.7118 - accuracy: 0.3565 - val_loss: 1.4309 - val_accuracy: 0.4762
# Epoch 2/25
#
# Epoch 00002: val_loss improved from 1.43090 to 1.17683, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 1.3620 - accuracy: 0.4980 - val_loss: 1.1768 - val_accuracy: 0.5776
# Epoch 3/25
#
# Epoch 00003: val_loss improved from 1.17683 to 1.16953, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 1.2356 - accuracy: 0.5518 - val_loss: 1.1695 - val_accuracy: 0.5796
# Epoch 4/25
#
# Epoch 00004: val_loss improved from 1.16953 to 1.01778, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 1.1543 - accuracy: 0.5825 - val_loss: 1.0178 - val_accuracy: 0.6362
# Epoch 5/25
#
# Epoch 00005: val_loss improved from 1.01778 to 0.99669, saving model to model.weights.best.hdf5
# 1407/1407 - 45s - loss: 1.0993 - accuracy: 0.6049 - val_loss: 0.9967 - val_accuracy: 0.6566
# Epoch 6/25
#
# Epoch 00006: val_loss did not improve from 0.99669
# 1407/1407 - 44s - loss: 1.0531 - accuracy: 0.6252 - val_loss: 1.0177 - val_accuracy: 0.6456
# Epoch 7/25
#
# Epoch 00007: val_loss improved from 0.99669 to 0.98852, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 1.0140 - accuracy: 0.6393 - val_loss: 0.9885 - val_accuracy: 0.6422
# Epoch 8/25
#
# Epoch 00008: val_loss improved from 0.98852 to 0.91678, saving model to model.weights.best.hdf5
# 1407/1407 - 45s - loss: 0.9839 - accuracy: 0.6500 - val_loss: 0.9168 - val_accuracy: 0.6802
# Epoch 9/25
#
# Epoch 00009: val_loss did not improve from 0.91678
# 1407/1407 - 44s - loss: 0.9495 - accuracy: 0.6633 - val_loss: 0.9363 - val_accuracy: 0.6716
# Epoch 10/25
#
# Epoch 00010: val_loss improved from 0.91678 to 0.87220, saving model to model.weights.best.hdf5
# 1407/1407 - 45s - loss: 0.9280 - accuracy: 0.6694 - val_loss: 0.8722 - val_accuracy: 0.6970
# Epoch 11/25
#
# Epoch 00011: val_loss did not improve from 0.87220
# 1407/1407 - 45s - loss: 0.9017 - accuracy: 0.6786 - val_loss: 0.8742 - val_accuracy: 0.6956
# Epoch 12/25
#
# Epoch 00012: val_loss did not improve from 0.87220
# 1407/1407 - 44s - loss: 0.8861 - accuracy: 0.6846 - val_loss: 0.8894 - val_accuracy: 0.6890
# Epoch 13/25
#
# Epoch 00013: val_loss improved from 0.87220 to 0.87119, saving model to model.weights.best.hdf5
# 1407/1407 - 45s - loss: 0.8671 - accuracy: 0.6946 - val_loss: 0.8712 - val_accuracy: 0.6958
# Epoch 14/25
#
# Epoch 00014: val_loss improved from 0.87119 to 0.83668, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 0.8525 - accuracy: 0.6978 - val_loss: 0.8367 - val_accuracy: 0.7122
# Epoch 15/25
#
# Epoch 00015: val_loss did not improve from 0.83668
# 1407/1407 - 45s - loss: 0.8410 - accuracy: 0.7050 - val_loss: 0.8672 - val_accuracy: 0.6980
# Epoch 16/25
#
# Epoch 00016: val_loss did not improve from 0.83668
# 1407/1407 - 45s - loss: 0.8337 - accuracy: 0.7063 - val_loss: 0.8492 - val_accuracy: 0.7090
# Epoch 17/25
#
# Epoch 00017: val_loss did not improve from 0.83668
# 1407/1407 - 44s - loss: 0.8084 - accuracy: 0.7183 - val_loss: 0.8459 - val_accuracy: 0.7058
# Epoch 18/25
#
# Epoch 00018: val_loss did not improve from 0.83668
# 1407/1407 - 45s - loss: 0.8095 - accuracy: 0.7142 - val_loss: 0.8534 - val_accuracy: 0.7046
# Epoch 19/25
#
# Epoch 00019: val_loss improved from 0.83668 to 0.83384, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 0.7973 - accuracy: 0.7188 - val_loss: 0.8338 - val_accuracy: 0.7120
# Epoch 20/25
#
# Epoch 00020: val_loss improved from 0.83384 to 0.83158, saving model to model.weights.best.hdf5
# 1407/1407 - 44s - loss: 0.7879 - accuracy: 0.7220 - val_loss: 0.8316 - val_accuracy: 0.7068
# Epoch 21/25
#
# Epoch 00021: val_loss did not improve from 0.83158
# 1407/1407 - 36s - loss: 0.7831 - accuracy: 0.7241 - val_loss: 0.8482 - val_accuracy: 0.7032
# Epoch 22/25
#
# Epoch 00022: val_loss did not improve from 0.83158
# 1407/1407 - 27s - loss: 0.7692 - accuracy: 0.7296 - val_loss: 0.8379 - val_accuracy: 0.7108
# Epoch 23/25
#
# Epoch 00023: val_loss improved from 0.83158 to 0.80920, saving model to model.weights.best.hdf5
# 1407/1407 - 27s - loss: 0.7587 - accuracy: 0.7328 - val_loss: 0.8092 - val_accuracy: 0.7146
# Epoch 24/25
#
# Epoch 00024: val_loss did not improve from 0.80920
# 1407/1407 - 27s - loss: 0.7608 - accuracy: 0.7318 - val_loss: 0.8196 - val_accuracy: 0.7156
# Epoch 25/25
#
# Epoch 00025: val_loss improved from 0.80920 to 0.80737, saving model to model.weights.best.hdf5
# 1407/1407 - 27s - loss: 0.7501 - accuracy: 0.7373 - val_loss: 0.8074 - val_accuracy: 0.7188

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.696399986743927

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
